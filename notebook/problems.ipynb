# %% [markdown]
# # Probability distribution problems

# %% [markdown]
# ## Binomial distribution
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment; for example, when you flip a coin, it can be either head or tails.

# %%
from scipy.stats import binom

# Define all the probability functions related to this distribution

def dbinom(x, size, prob = 0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Generates random variables from the binomial distribution
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Binomial(10, 0.2) distribution, where n = 10 is the number of trials and p = 0.2 is the probability of success in a single trial
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Exercise 1
#
# Write the above functions but for both normal and uniform distributions.

# %%
# TODO
from scipy.stats import norm
from scipy.stats import uniform

# Point estimate norm
def enorm(x,mean=0,stdev=1):
    result = norm.pdf(x,loc=mean,scale=stdev)
    return result

# Cumulative distribution norm
def cnorm(x,mean=0,stdev=1):
    result = norm.cdf(x,loc=mean,scale=stdev)
    return result

# Percent point distribution norm
def pnorm(p_value,mean=0,stdev=1):
    result = norm.ppf(p_value,loc=mean,scale=stdev)
    return result

# Random variables norm
def rnorm(size,mean=0,stdev=1):
    result = norm.rvs(loc=mean,scale=stdev,size=size)
    return result

# Point estimate uniform
def euniform(a,b):
    x = np.linspace(a,b,150)
    result = uniform.pdf(x,loc=a,scale=(b-a))
    return result

# Cumulative distribution uniform
def cuniform(a,b):
    x = np.linspace(a,b,150)
    result = uniform.cdf(x,loc=a,scale=(b-a))
    return result

# Percent point distribution uniform
def puniform(p_value,a,b):
    result = uniform.ppf(p_value,loc=a,scale=(b-a))
    return result

# Random variables uniform
def runiform(a,b,size):
    result = uniform.rvs(size=size,loc=a,scale=(b-a))
    return result

x = np.linspace(-5, 5, 100) 

print(f'PDF norm {enorm(x)}')
print(f'CDF norm {cnorm(x)}')
print(f'PPF norm {pnorm(p_value=0.8)}')
print(f'RVS norm {rnorm(size=10)}')
print(f'PDF uniform {euniform(0,10)}')
print(f'CDF uniform {cuniform(0,10)}')
print(f'PPF uniform {puniform(0.8,0,10)}')
print(f'RVS uniform {runiform(0,10,size=50)}')

y_norm = enorm(x)
plt.figure()
plt.plot(x, y_norm, label="Normal Distribution PDF")
plt.title("Normal Distribution - Probability Density Function (PDF)")
plt.xlabel("x")
plt.ylabel("Density")
plt.legend()

cum_norm = cnorm(x)
plt.figure()
plt.plot(x, cum_norm, label="Normal Distribution CDF")
plt.title("Normal Distribution - Cumulative Distribution Function (CDF)")
plt.xlabel("x")
plt.ylabel("Cumulative Probability")
plt.legend()

p_values = np.linspace(0, 1, 100)
p_norm = [pnorm(p) for p in p_values]
plt.figure()
plt.plot(p_values, p_norm, label="Normal Distribution PPF")
plt.title("Normal Distribution - Percent Point Function (PPF)")
plt.xlabel("Cumulative Probability (p)")
plt.ylabel("x (Quantile)")
plt.legend()

a = 0
b = 10
x_uniform = euniform(a, b)

plt.figure()
plt.plot(np.linspace(a, b, 150), x_uniform, label="Uniform Distribution PDF", color='green')
plt.title("Uniform Distribution - Probability Density Function (PDF)")
plt.xlabel("x")
plt.ylabel("Density")
plt.legend()

cum_uniform = cuniform(a, b)
plt.figure()
plt.plot(np.linspace(a, b, 150), cum_uniform, label="Uniform Distribution CDF", color='green')
plt.title("Uniform Distribution - Cumulative Distribution Function (CDF)")
plt.xlabel("x")
plt.ylabel("Cumulative Probability")
plt.legend()

p_values = np.linspace(0, 1, 100)
p_uniform = [puniform(p, a, b) for p in p_values]
plt.figure()
plt.plot(p_values, p_uniform, label="Uniform Distribution PPF", color='green')
plt.title("Uniform Distribution - Percent Point Function (PPF)")
plt.xlabel("Cumulative Probability (p)")
plt.ylabel("x (Quantile)")
plt.legend()

plt.show()
# Out:
# PDF norm [1.48671951e-06 2.45106104e-06 3.99989037e-06 6.46116639e-06
#  1.03310066e-05 1.63509589e-05 2.56160812e-05 3.97238224e-05
#  6.09759040e-05 9.26476353e-05 1.39341123e-04 2.07440309e-04
#  3.05686225e-04 4.45889725e-04 6.43795498e-04 9.20104770e-04
#  1.30165384e-03 1.82273110e-03 2.52649578e-03 3.46643792e-03
#  4.70779076e-03 6.32877643e-03 8.42153448e-03 1.10925548e-02
#  1.44624148e-02 1.86646099e-02 2.38432745e-02 3.01496139e-02
#  3.77369231e-02 4.67541424e-02 5.73380051e-02 6.96039584e-02
#  8.36361772e-02 9.94771388e-02 1.17117360e-01 1.36486009e-01
#  1.57443188e-01 1.79774665e-01 2.03189836e-01 2.27323506e-01
#  2.51741947e-01 2.75953371e-01 2.99422683e-01 3.21590023e-01
#  3.41892294e-01 3.59786558e-01 3.74773979e-01 3.86422853e-01
#  3.94389234e-01 3.98433802e-01 3.98433802e-01 3.94389234e-01
#  3.86422853e-01 3.74773979e-01 3.59786558e-01 3.41892294e-01
#  3.21590023e-01 2.99422683e-01 2.75953371e-01 2.51741947e-01
# ...
